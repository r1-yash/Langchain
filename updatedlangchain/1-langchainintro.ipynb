# %% [markdown]
# ### Langchain Version V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.agents import create_agent 



##so first I just call and llm provide itinput and it gives output

agent = create_agent(
    model="google_genai:gemini-2.5-flash",
    tools = [],
    system_prompt = "Hi"
)
agent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/Langchain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:119, in _import_module(module, class_name)
#     118 try:
# --> 119     return importlib.import_module(module)
#     120 except ImportError as e:
#     121     # Extract package name from module path (e.g., "langchain_azure_ai.chat_models"
#     122     # becomes "langchain-azure-ai")
#
# File /opt/anaconda3/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'langchain_google_vertexai'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4
#       5 ##so first I just call and llm provide itinput and it gives output
#       6
# ----> 7 agent = create_agent(
#       8     model="gemini-2.5-flash",
#       9     tools = [],
#      10     system_prompt = "Hi"
#
# File ~/Desktop/Langchain/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:964, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache, transformers)
#     962 # init chat model
#     963 if isinstance(model, str):
# --> 964     model = init_chat_model(model)
#     966 # Convert system_prompt to SystemMessage if needed
#     967 system_message: SystemMessage | None = None
#
# File ~/Desktop/Langchain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:496, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     488     warnings.warn(
#     489         f"{config_prefix=} has been set but no fields are configurable. Set "
#     490         f"`configurable_fields=(...)` to specify the model params that are "
#     491         f"configurable.",
#     492         stacklevel=2,
#     493     )
#     495 if not configurable_fields:
# --> 496     return _init_chat_model_helper(
#     497         cast("str", model),
#     498         model_provider=model_provider,
#     499         **kwargs,
#     500     )
#     501 if model:
#     502     kwargs["model"] = model
#
# File ~/Desktop/Langchain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:519, in _init_chat_model_helper(model, model_provider, **kwargs)
#     512 def _init_chat_model_helper(
#     513     model: str,
#     514     *,
#     515     model_provider: str | None = None,
#     516     **kwargs: Any,
#     517 ) -> BaseChatModel:
#     518     model, model_provider = _parse_model(model, model_provider)
# --> 519     creator_func = _get_chat_model_creator(model_provider)
#     520     return creator_func(model=model, **kwargs)
#
# File ~/Desktop/Langchain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:159, in _get_chat_model_creator(provider)
#     157 pkg, class_name, creator_func = _BUILTIN_PROVIDERS[provider]
#     158 try:
# --> 159     module = _import_module(pkg, class_name)
#     160 except ImportError as e:
#     161     if provider != "ollama":
#
# File ~/Desktop/Langchain/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:128, in _import_module(module, class_name)
#     123 pkg = module.split(".", maxsplit=1)[0].replace("_", "-")
#     124 msg = (
#     125     f"Initializing {class_name} requires the {pkg} package. Please install it "
#     126     f"with `pip install {pkg}`"
#     127 )
# --> 128 raise ImportError(msg) from e
#
# ImportError: Initializing ChatVertexAI requires the langchain-google-vertexai package. Please install it with `pip install langchain-google-vertexai`
